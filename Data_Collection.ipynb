# %%
import pandas as pd
from binance.client import Client

# %%
api_key='RWEwFk9pTKhARfqoHZVVS1zjxORpssTyVKncuD1kTGLGRdEXsUCM7s1oXf4ZAinr'
api_secret='hITx7vdHtAST0DlkYOBETjC9i93c6uGriLNEQyYev25psdB2vDPR0RjqPjDI9m2D'
Client=Client(api_key, api_secret)

# %%
def get_historical_klines(symbol, interval, start_str, end_str=None):
    
    klines = Client.get_historical_klines(symbol, interval, start_str, end_str)
    bitcoin_df= pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume',
                                            'close_time', 'quote_asset_volume', 'number_of_trades',
                                            'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
    bitcoin_df= bitcoin_df[['timestamp', 'open', 'high', 'low', 'close', 'volume',
                                            'close_time', 'quote_asset_volume', 'number_of_trades',
                                            'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']]
    bitcoin_df['timestamp'] = pd.to_datetime(bitcoin_df['timestamp'], unit='ms')
    bitcoin_df.set_index('timestamp', inplace=True)
    bitcoin_df = bitcoin_df.astype(float)
    return bitcoin_df

# %%
symbol = 'BTCUSDT'
interval = '1h'
start_str = '1 Jan 2023'
end_str = '1 Apr 2025'

# %%
bitcoin_df = get_historical_klines(symbol, interval, start_str, end_str)
print(bitcoin_df)
# Out:
# C:\Users\Roopak Mallik\AppData\Local\Temp\ipykernel_4784\703949686.py:3: DeprecationWarning: Parsing dates involving a day of month without a year specified is ambiguious
# and fails to parse leap day. The default behavior will change in Python 3.15
# to either always raise an exception or to use a different default year (TBD).
# To avoid trouble, add a specific year to the input & format.
# See https://github.com/python/cpython/issues/70647.
#   klines = Client.get_historical_klines(symbol, interval, start_str, end_str)
#                          open      high       low     close      volume  \
# timestamp
# 2023-01-01 00:00:00  16541.77  16545.70  16508.39  16529.67  4364.83570
# 2023-01-01 01:00:00  16529.59  16556.80  16525.78  16551.47  3590.06669
# 2023-01-01 02:00:00  16551.47  16559.77  16538.14  16548.19  3318.84038
# 2023-01-01 03:00:00  16548.19  16548.19  16518.21  16533.04  4242.08050
# 2023-01-01 04:00:00  16533.04  16535.97  16511.92  16521.85  4285.00909
# ...

# %%
bitcoin_df
# Out:
#                          open      high       low     close      volume  \
# timestamp
# 2023-01-01 00:00:00  16541.77  16545.70  16508.39  16529.67  4364.83570
# 2023-01-01 01:00:00  16529.59  16556.80  16525.78  16551.47  3590.06669
# 2023-01-01 02:00:00  16551.47  16559.77  16538.14  16548.19  3318.84038
# 2023-01-01 03:00:00  16548.19  16548.19  16518.21  16533.04  4242.08050
# 2023-01-01 04:00:00  16533.04  16535.97  16511.92  16521.85  4285.00909
# ...                       ...       ...       ...       ...         ...
# 2025-03-31 20:00:00  82462.26  82846.20  82350.84  82431.32   701.19812
# 2025-03-31 21:00:00  82431.32  82752.18  82422.00  82563.99   342.52865
# 2025-03-31 22:00:00  82563.99  82571.98  82265.10  82409.99   260.87647
# 2025-03-31 23:00:00  82410.00  82886.80  82283.90  82550.01   383.74846
# 2025-04-01 00:00:00  82550.00  82837.38  82432.74  82651.10   526.95922
#
#                        close_time  quote_asset_volume  number_of_trades  \
# timestamp
# ...

# %%
def get_historical_klines(symbol, interval, start_str, end_str=None):
    
    klines = Client.get_historical_klines(symbol, interval, start_str, end_str)
    ethereum_df= pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume',
                                            'close_time', 'quote_asset_volume', 'number_of_trades',
                                            'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
    ethereum_df= ethereum_df[['timestamp', 'open', 'high', 'low', 'close', 'volume',
                                            'close_time', 'quote_asset_volume', 'number_of_trades',
                                            'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore']]
    ethereum_df['timestamp'] = pd.to_datetime(ethereum_df['timestamp'], unit='ms')
    ethereum_df.set_index('timestamp', inplace=True)
    ethereum_df = ethereum_df.astype(float)
    return ethereum_df

# %%
symbol = 'ETHUSDT'
interval = '1h'
start_str = '1 Jan 2023'
end_str = '1 Apr 2025'

# %%
ethereum_df = get_historical_klines(symbol, interval, start_str, end_str)
print(ethereum_df)
# Out:
# C:\Users\Roopak Mallik\AppData\Local\Temp\ipykernel_4784\2314975394.py:3: DeprecationWarning: Parsing dates involving a day of month without a year specified is ambiguious
# and fails to parse leap day. The default behavior will change in Python 3.15
# to either always raise an exception or to use a different default year (TBD).
# To avoid trouble, add a specific year to the input & format.
# See https://github.com/python/cpython/issues/70647.
#   klines = Client.get_historical_klines(symbol, interval, start_str, end_str)
#                         open     high      low    close      volume  \
# timestamp
# 2023-01-01 00:00:00  1196.13  1196.70  1192.72  1194.09   5889.3840
# 2023-01-01 01:00:00  1194.09  1196.37  1193.84  1196.02   3157.2079
# 2023-01-01 02:00:00  1196.01  1196.74  1194.11  1195.40   3752.0476
# 2023-01-01 03:00:00  1195.41  1195.41  1191.71  1194.04   7493.4207
# 2023-01-01 04:00:00  1194.05  1194.05  1190.57  1192.92   6409.2491
# ...

# %%
ethereum_df
# Out:
#                         open     high      low    close      volume  \
# timestamp
# 2023-01-01 00:00:00  1196.13  1196.70  1192.72  1194.09   5889.3840
# 2023-01-01 01:00:00  1194.09  1196.37  1193.84  1196.02   3157.2079
# 2023-01-01 02:00:00  1196.01  1196.74  1194.11  1195.40   3752.0476
# 2023-01-01 03:00:00  1195.41  1195.41  1191.71  1194.04   7493.4207
# 2023-01-01 04:00:00  1194.05  1194.05  1190.57  1192.92   6409.2491
# ...                      ...      ...      ...      ...         ...
# 2025-03-31 20:00:00  1827.71  1834.74  1818.64  1819.61  14738.9690
# 2025-03-31 21:00:00  1819.60  1829.50  1819.19  1824.72   8655.4692
# 2025-03-31 22:00:00  1824.72  1825.16  1816.40  1824.68   8282.9153
# 2025-03-31 23:00:00  1824.68  1831.90  1820.31  1822.43  10905.8681
# 2025-04-01 00:00:00  1822.43  1843.00  1817.88  1831.94  22628.8655
#
#                        close_time  quote_asset_volume  number_of_trades  \
# timestamp
# ...

# %%
bitcoin_df.to_csv('bitcoin_data.csv')
ethereum_df.to_csv('ethereum_data.csv')
